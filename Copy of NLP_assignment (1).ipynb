# %% [markdown]
# # Natural Language Processing </a>
#
# ## Assignment: K Nearest Neighbors Model for the IMDB Movie Review Dataset
#
# For the final project, build a K Nearest Neighbors model to predict the sentiment (positive or negative) of movie reviews. The dataset is originally hosted here: http://ai.stanford.edu/~amaas/data/sentiment/
#
# Use the notebooks from the class and implement the model, train and test with the corresponding datasets.
#
# You can follow these steps:
# 1. Read training-test data (Given)
# 2. Train a KNN classifier (Implement)
# 3. Make predictions on your test dataset (Implement)
#
# __You can use the KNN Classifier from here: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html__

# %% [markdown]
# ## 1. Reading the dataset
#
# We will use the __pandas__ library to read our dataset.

# %% [markdown]
# #### __Training data:__
# Let's read our training data. Here, we have the text and label fields. Labe is 1 for positive reviews and 0 for negative reviews.

# %%
import pandas as pd

train_df = pd.read_csv('https://raw.githubusercontent.com/aws-samples/aws-machine-learning-university-accelerated-nlp/master/data/final_project/imdb_train.csv', header=0)
train_df.head()
# Out:
#                                                 text  label
# 0  This movie makes me want to throw up every tim...      0
# 1  Listening to the director's commentary confirm...      0
# 2  One of the best Tarzan films is also one of it...      1
# 3  Valentine is now one of my favorite slasher fi...      1
# 4  No mention if Ann Rivers Siddons adapted the m...      0

# %%
print('The shape of the dataset is:', train_df.shape)
# Out:
# The shape of the dataset is: (25000, 2)

# %% [markdown]
# #### __Test data:__

# %%
import pandas as pd

test_df = pd.read_csv('https://raw.githubusercontent.com/aws-samples/aws-machine-learning-university-accelerated-nlp/master/data/final_project/imdb_test.csv', header=0)
test_df.head()
# Out:
#                                                 text  label
# 0  What I hoped for (or even expected) was the we...      0
# 1  Garden State must rate amongst the most contri...      0
# 2  There is a lot wrong with this film. I will no...      1
# 3  To qualify my use of "realistic" in the summar...      1
# 4  Dirty War is absolutely one of the best politi...      1

# %%
print('The shape of the dataset is:', test_df.shape)
# Out:
# The shape of the dataset is: (25000, 2)

# %%
print(test_df.isna().sum())
# Out:
# text     0
# label    0
# dtype: int64

# %%
train_df["label"].value_counts()
# Out:
# 0    12500
# 1    12500
# Name: label, dtype: int64

# %%
test_df["label"].value_counts()
# Out:
# 0    12500
# 1    12500
# Name: label, dtype: int64

# %% [markdown]
# #x train, y train
# #x test, y test
#
# #Data Processing With Pipeline (NLP_KNN 5)

# %% [markdown]
# ## 2. Train a KNN Classifier
# Here, you will apply pre-processing operations we covered in the class. Then, you can split your dataset to training and validation here. For your first submission, you will use __K Nearest Neighbors Classifier__. It is available [here](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html).

# %%
# Install the library and functions
import nltk

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk, re
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize

# Let's get a list of stop words from the NLTK library
stop = stopwords.words('english')

# These words are important for our problem. We don't want to remove them.
excluding = ['against', 'not', 'don', "don't",'ain', 'aren', "aren't", 'couldn', "couldn't",
             'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 
             'haven', "haven't", 'isn', "isn't", 'mightn', "mightn't", 'mustn', "mustn't",
             'needn', "needn't",'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', 
             "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# New stop word list
stop_words = [word for word in stop if word not in excluding]

snow = SnowballStemmer('english')

def process_text(texts): 
    final_text_list=[]
    for sent in texts:
        
        # Check if the sentence is a missing value
        if isinstance(sent, str) == False:
            sent = ""
            
        filtered_sentence=[]
        
        sent = sent.lower() # Lowercase 
        sent = sent.strip() # Remove leading/trailing whitespace
        sent = re.sub('\s+', ' ', sent) # Remove extra space and tabs
        sent = re.compile('<.*?>').sub('', sent) # Remove HTML tags/markups:
        
        for w in word_tokenize(sent):
            # We are applying some custom filtering here, feel free to try different things
            # Check if it is not numeric and its length>2 and not in stop words
            if(not w.isnumeric()) and (len(w)>2) and (w not in stop_words):  
                # Stem and add to filtered list
                filtered_sentence.append(snow.stem(w))
        final_string = " ".join(filtered_sentence) #final string of cleaned words
 
        final_text_list.append(final_string)
        
    return final_text_list

# %%
from sklearn.model_selection import train_test_split

X=train_df[["text"]]
Y=train_df["label"]
X_train, X_val, y_train, y_val = train_test_split(X,
                                                  Y,
                                                  test_size=0.10,
                                                  shuffle=True,
                                                  random_state=324
                                                 )

# %%
print("Processing the text fields")
train_text_list = process_text(X_train["text"].tolist())
val_text_list = process_text(X_val["text"].tolist())
# Out:
# Processing the text fields

# %% [markdown]
# ## 3. Make predictions on your test dataset
#
# Once we select our best performing model, we can use it to make predictions on the test dataset. You can simply use __.fit()__ function with your training data to use the best performing K value and use __.predict()__ with your test data to get your test predictions.

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier



pipeline = Pipeline([
    ( 'text_vect', TfidfVectorizer(use_idf=True,
                                  max_features=70)),
    ('knn', KNeighborsClassifier())  
                                ])


# Visualize the pipeline
# This will come in handy especially when building more complex pipelines, stringing together multiple preprocessing steps
from sklearn import set_config
set_config(display='diagram')
pipeline
# Out:
# Pipeline(steps=[('text_vect', TfidfVectorizer(max_features=70)),
#                 ('knn', KNeighborsClassifier())])

# %%
# We using lists of processed text fields 
X_train = train_text_list
X_val = val_text_list

# Fit the Pipeline to training data
pipeline.fit(X_train, y_train.values)
# Out:
# Pipeline(steps=[('text_vect', TfidfVectorizer(max_features=70)),
#                 ('knn', KNeighborsClassifier())])

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Use the fitted pipeline to make predictions on the validation dataset
val_predictions = pipeline.predict(X_val)
print(confusion_matrix(y_val.values, val_predictions))
print(classification_report(y_val.values, val_predictions))
print("Accuracy (validation):", accuracy_score(y_val.values, val_predictions))
# Out:
# [[862 418]
#  [401 819]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.67      0.68      1280
#            1       0.66      0.67      0.67      1220
#
#     accuracy                           0.67      2500
#    macro avg       0.67      0.67      0.67      2500
# weighted avg       0.67      0.67      0.67      2500
#
# Accuracy (validation): 0.6724

# %% [markdown]
# # **TEST_DF**

# %%
from sklearn.model_selection import train_test_split

Xx=test_df[["text"]]
Yy=test_df["label"]
Xx_test, Xx_val, yy_test, yy_val = train_test_split(Xx,
                                                  Yy,
                                                  test_size=0.10,
                                                  shuffle=True,
                                                  random_state=324
                                                 )

# %%
print("Processing the text fields")
test_text_list = process_text(Xx_test["text"].tolist())
val_text_list = process_text(Xx_val["text"].tolist())
# Out:
# Processing the text fields

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier


pipeline = Pipeline([
    ( 'text_vect', TfidfVectorizer(use_idf=True,
                                  max_features=56)),
    ('knn', KNeighborsClassifier())  
                                ])


# Visualize the pipeline
# This will come in handy especially when building more complex pipelines, stringing together multiple preprocessing steps
from sklearn import set_config
set_config(display='diagram')
pipeline
# Out:
# Pipeline(steps=[('text_vect', TfidfVectorizer(max_features=56)),
#                 ('knn', KNeighborsClassifier())])

# %%
# We using lists of processed text fields 
Xx_test = test_text_list
Xx_val = val_text_list

# Fit the Pipeline to training data
pipeline.fit(Xx_test, yy_test.values)
# Out:
# Pipeline(steps=[('text_vect', TfidfVectorizer(max_features=56)),
#                 ('knn', KNeighborsClassifier())])

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Use the fitted pipeline to make predictions on the validation dataset
val_predictions = pipeline.predict(Xx_val)
print(confusion_matrix(yy_val.values, val_predictions))
print(classification_report(yy_val.values, val_predictions))
print("Accuracy (validation):", accuracy_score(yy_val.values, val_predictions))
# Out:
# [[833 439]
#  [380 848]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.65      0.67      1272
#            1       0.66      0.69      0.67      1228
#
#     accuracy                           0.67      2500
#    macro avg       0.67      0.67      0.67      2500
# weighted avg       0.67      0.67      0.67      2500
#
# Accuracy (validation): 0.6724

# %% [markdown]
# # **Comments**

# %% [markdown]
# **The highest accuracy for both the training data and test data was 0.6724, when i changed the 70 and 56 respectively. This accuracy was also achieved when using TfidfVectorizer rather than CountVectorizer and letting it be "True"**
